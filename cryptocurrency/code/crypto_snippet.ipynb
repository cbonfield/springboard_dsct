# %%
# Import statements (standard)
import math
import time
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Import statements (custom)
import helper_functions as hf
import granger_causality as gc

# %%
#df = pd.read_csv('~/Desktop/Springboard/Cryptocurrency/cleaned_crypto_closing_prices.csv', index_col='time')
df = pd.read_csv('../data/cleaned_crypto_closing_prices.csv', index_col='time')

# %%
df.head()
# Out:
#                 BTC_USD    DASH_USD   ETH_USD  LTC_USD    XMR_USD
# time
# 9/17/17 7:00   3573.556  294.153333  246.1225   49.590  92.036667
# 9/17/17 8:00   3595.146  296.706667  246.4850   49.892  92.756667
# 9/17/17 9:00   3670.806  302.993333  253.5550   51.370  94.123333
# 9/17/17 10:00  3669.620  301.620000  253.1875   50.940  95.440000
# 9/17/17 11:00  3688.812  304.310000  255.5600   51.226  95.600000

# %% [markdown]
# ## Test for Stationarity before/after differencing:

# %% [markdown]
# Prior to looking into Granger causality, we need to check to ensure that our time series are indeed stationary. To do so, I'll use the augmented Dickey-Fuller test (`adfuller` from `statsmodels`: http://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.adfuller.html).

# %%
# BEFORE
for i in range(len(df.columns)):
    crypto_str = df.columns[i]
    crypto_df = df[crypto_str]
    print('%s:' % crypto_str)

    adf_test_results = hf.adf_stationarity_test(crypto_df, al='AIC')
    print(adf_test_results)
    print('\n')
# Out:
# BTC_USD:
# Number of Data Points    1973.000000
# Number of Lags             26.000000
# Test Statistic              0.597288
# p-value                     0.987549
# dtype: float64
#
#
# DASH_USD:
# Number of Data Points    1974.000000
# Number of Lags             25.000000
# Test Statistic              0.442954
# p-value                     0.983032
# dtype: float64
#
#
# ETH_USD:
# Number of Data Points    1973.000000
# Number of Lags             26.000000
# Test Statistic             -0.348741
# p-value                     0.918312
# dtype: float64
#
#
# LTC_USD:
# Number of Data Points    1973.000000
# Number of Lags             26.000000
# Test Statistic              1.667423
# p-value                     0.998046
# dtype: float64
#
#
# XMR_USD:
# Number of Data Points    1973.000000
# Number of Lags             26.000000
# Test Statistic              1.402269
# p-value                     0.997124
# dtype: float64

# %%
diff_df = hf.difference_prices(df)

# %%
# AFTER
for i in range(len(diff_df.columns)):
    crypto_str = diff_df.columns[i]
    crypto_df = diff_df[crypto_str]
    print('%s:' % crypto_str)

    adf_test_results = hf.adf_stationarity_test(crypto_df, al='AIC')
    print(adf_test_results)
    print('\n')
# Out:
# BTC_USD:
# Number of Data Points    1.972000e+03
# Number of Lags           2.600000e+01
# Test Statistic          -7.394542e+00
# p-value                  7.840737e-11
# dtype: float64
#
#
# DASH_USD:
# Number of Data Points    1.972000e+03
# Number of Lags           2.600000e+01
# Test Statistic          -8.092700e+00
# p-value                  1.364732e-12
# dtype: float64
#
#
# ETH_USD:
# Number of Data Points    1.972000e+03
# Number of Lags           2.600000e+01
# Test Statistic          -9.243282e+00
# p-value                  1.561619e-15
# dtype: float64
#
#
# LTC_USD:
# Number of Data Points    1.972000e+03
# Number of Lags           2.600000e+01
# Test Statistic          -1.096753e+01
# p-value                  8.032989e-20
# dtype: float64
#
#
# XMR_USD:
# Number of Data Points    1.973000e+03
# Number of Lags           2.500000e+01
# Test Statistic          -8.688091e+00
# p-value                  4.110910e-14
# dtype: float64

# %% [markdown]
# It's reasonable that we've achieved stationarity for each of our time series by taking the first difference.

# %% [markdown]
# ## Look for Granger Causality

# %% [markdown]
# With the first difference of each time series shown to be stationary, we can now look for Granger causality. We'll do so using the package `grangercausalitytests` (http://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.grangercausalitytests.html), available as part of `statsmodels`.
#
# Based on my interpretation of the underlying source code, the parameter `max_lags` (which I've set to 48 for now) sets the number of maximum lags *included* in the test, meaning that we are performing the test for each value up to/including `max_lags`, and at each intermediate value, we include all of the lags up to/including that value in the test.

# %%
n_cols = 5
for i in range(n_cols):
    for j in range(n_cols):
        if i == j:
            continue
        else:
            print('Series 1: ', diff_df.columns[i])
            print('Series 2: ', diff_df.columns[j])
            gc_results = gc.granger_causality(diff_df, i, j)
            print('*******************************')
            print('\n')
# Out:
# Series 1:  BTC_USD
# Series 2:  DASH_USD
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0164  , p=0.8982  , df_denom=1995, df_num=1
# ssr based chi2 test:   chi2=0.0164  , p=0.8981  , df=1
# likelihood ratio test: chi2=0.0164  , p=0.8981  , df=1
# parameter F test:         F=0.0164  , p=0.8982  , df_denom=1995, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.2566  , p=0.0053  , df_denom=1992, df_num=2
# ssr based chi2 test:   chi2=10.5397 , p=0.0051  , df=2
# likelihood ratio test: chi2=10.5119 , p=0.0052  , df=2
# parameter F test:         F=5.2566  , p=0.0053  , df_denom=1992, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.4514  , p=0.0001  , df_denom=1989, df_num=3
# ssr based chi2 test:   chi2=22.4328 , p=0.0001  , df=3
# likelihood ratio test: chi2=22.3076 , p=0.0001  , df=3
# parameter F test:         F=7.4514  , p=0.0001  , df_denom=1989, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=5.9098  , p=0.0001  , df_denom=1986, df_num=4
# ssr based chi2 test:   chi2=23.7463 , p=0.0001  , df=4
# likelihood ratio test: chi2=23.6060 , p=0.0001  , df=4
# parameter F test:         F=5.9098  , p=0.0001  , df_denom=1986, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=5.2874  , p=0.0001  , df_denom=1983, df_num=5
# ssr based chi2 test:   chi2=26.5838 , p=0.0001  , df=5
# likelihood ratio test: chi2=26.4082 , p=0.0001  , df=5
# parameter F test:         F=5.2874  , p=0.0001  , df_denom=1983, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=6.5780  , p=0.0000  , df_denom=1980, df_num=6
# ssr based chi2 test:   chi2=39.7271 , p=0.0000  , df=6
# likelihood ratio test: chi2=39.3363 , p=0.0000  , df=6
# parameter F test:         F=6.5780  , p=0.0000  , df_denom=1980, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=8.2714  , p=0.0000  , df_denom=1977, df_num=7
# ssr based chi2 test:   chi2=58.3390 , p=0.0000  , df=7
# likelihood ratio test: chi2=57.5011 , p=0.0000  , df=7
# parameter F test:         F=8.2714  , p=0.0000  , df_denom=1977, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=8.3888  , p=0.0000  , df_denom=1974, df_num=8
# ssr based chi2 test:   chi2=67.6881 , p=0.0000  , df=8
# likelihood ratio test: chi2=66.5629 , p=0.0000  , df=8
# parameter F test:         F=8.3888  , p=0.0000  , df_denom=1974, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=9.4153  , p=0.0000  , df_denom=1971, df_num=9
# ssr based chi2 test:   chi2=85.5542 , p=0.0000  , df=9
# likelihood ratio test: chi2=83.7662 , p=0.0000  , df=9
# parameter F test:         F=9.4153  , p=0.0000  , df_denom=1971, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=8.9117  , p=0.0000  , df_denom=1968, df_num=10
# ssr based chi2 test:   chi2=90.0682 , p=0.0000  , df=10
# likelihood ratio test: chi2=88.0885 , p=0.0000  , df=10
# parameter F test:         F=8.9117  , p=0.0000  , df_denom=1968, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=8.3283  , p=0.0000  , df_denom=1965, df_num=11
# ssr based chi2 test:   chi2=92.6837 , p=0.0000  , df=11
# likelihood ratio test: chi2=90.5880 , p=0.0000  , df=11
# parameter F test:         F=8.3283  , p=0.0000  , df_denom=1965, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=8.1855  , p=0.0000  , df_denom=1962, df_num=12
# ssr based chi2 test:   chi2=99.4771 , p=0.0000  , df=12
# likelihood ratio test: chi2=97.0671 , p=0.0000  , df=12
# parameter F test:         F=8.1855  , p=0.0000  , df_denom=1962, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=8.3040  , p=0.0000  , df_denom=1959, df_num=13
# ssr based chi2 test:   chi2=109.4404, p=0.0000  , df=13
# likelihood ratio test: chi2=106.5313, p=0.0000  , df=13
# parameter F test:         F=8.3040  , p=0.0000  , df_denom=1959, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=7.8237  , p=0.0000  , df_denom=1956, df_num=14
# ssr based chi2 test:   chi2=111.1555, p=0.0000  , df=14
# likelihood ratio test: chi2=108.1547, p=0.0000  , df=14
# parameter F test:         F=7.8237  , p=0.0000  , df_denom=1956, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=7.3049  , p=0.0000  , df_denom=1953, df_num=15
# ssr based chi2 test:   chi2=111.3132, p=0.0000  , df=15
# likelihood ratio test: chi2=108.3027, p=0.0000  , df=15
# parameter F test:         F=7.3049  , p=0.0000  , df_denom=1953, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=6.7059  , p=0.0000  , df_denom=1950, df_num=16
# ssr based chi2 test:   chi2=109.1109, p=0.0000  , df=16
# likelihood ratio test: chi2=106.2148, p=0.0000  , df=16
# parameter F test:         F=6.7059  , p=0.0000  , df_denom=1950, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=6.2686  , p=0.0000  , df_denom=1947, df_num=17
# ssr based chi2 test:   chi2=108.4818, p=0.0000  , df=17
# likelihood ratio test: chi2=105.6171, p=0.0000  , df=17
# parameter F test:         F=6.2686  , p=0.0000  , df_denom=1947, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=5.6733  , p=0.0000  , df_denom=1944, df_num=18
# ssr based chi2 test:   chi2=104.0632, p=0.0000  , df=18
# likelihood ratio test: chi2=101.4220, p=0.0000  , df=18
# parameter F test:         F=5.6733  , p=0.0000  , df_denom=1944, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=5.5842  , p=0.0000  , df_denom=1941, df_num=19
# ssr based chi2 test:   chi2=108.2313, p=0.0000  , df=19
# likelihood ratio test: chi2=105.3768, p=0.0000  , df=19
# parameter F test:         F=5.5842  , p=0.0000  , df_denom=1941, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=5.2849  , p=0.0000  , df_denom=1938, df_num=20
# ssr based chi2 test:   chi2=107.9346, p=0.0000  , df=20
# likelihood ratio test: chi2=105.0940, p=0.0000  , df=20
# parameter F test:         F=5.2849  , p=0.0000  , df_denom=1938, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=4.9813  , p=0.0000  , df_denom=1935, df_num=21
# ssr based chi2 test:   chi2=106.9327, p=0.0000  , df=21
# likelihood ratio test: chi2=104.1424, p=0.0000  , df=21
# parameter F test:         F=4.9813  , p=0.0000  , df_denom=1935, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=4.8375  , p=0.0000  , df_denom=1932, df_num=22
# ssr based chi2 test:   chi2=108.9044, p=0.0000  , df=22
# likelihood ratio test: chi2=106.0107, p=0.0000  , df=22
# parameter F test:         F=4.8375  , p=0.0000  , df_denom=1932, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=5.3280  , p=0.0000  , df_denom=1929, df_num=23
# ssr based chi2 test:   chi2=125.5295, p=0.0000  , df=23
# likelihood ratio test: chi2=121.7034, p=0.0000  , df=23
# parameter F test:         F=5.3280  , p=0.0000  , df_denom=1929, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=5.1450  , p=0.0000  , df_denom=1926, df_num=24
# ssr based chi2 test:   chi2=126.6205, p=0.0000  , df=24
# likelihood ratio test: chi2=122.7272, p=0.0000  , df=24
# parameter F test:         F=5.1450  , p=0.0000  , df_denom=1926, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=5.4388  , p=0.0000  , df_denom=1923, df_num=25
# ssr based chi2 test:   chi2=139.5757, p=0.0000  , df=25
# likelihood ratio test: chi2=134.8621, p=0.0000  , df=25
# parameter F test:         F=5.4388  , p=0.0000  , df_denom=1923, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=5.2028  , p=0.0000  , df_denom=1920, df_num=26
# ssr based chi2 test:   chi2=139.0060, p=0.0000  , df=26
# likelihood ratio test: chi2=134.3277, p=0.0000  , df=26
# parameter F test:         F=5.2028  , p=0.0000  , df_denom=1920, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=5.0179  , p=0.0000  , df_denom=1917, df_num=27
# ssr based chi2 test:   chi2=139.3700, p=0.0000  , df=27
# likelihood ratio test: chi2=134.6654, p=0.0000  , df=27
# parameter F test:         F=5.0179  , p=0.0000  , df_denom=1917, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=4.8477  , p=0.0000  , df_denom=1914, df_num=28
# ssr based chi2 test:   chi2=139.7770, p=0.0000  , df=28
# likelihood ratio test: chi2=135.0433, p=0.0000  , df=28
# parameter F test:         F=4.8477  , p=0.0000  , df_denom=1914, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=4.8031  , p=0.0000  , df_denom=1911, df_num=29
# ssr based chi2 test:   chi2=143.5900, p=0.0000  , df=29
# likelihood ratio test: chi2=138.5982, p=0.0000  , df=29
# parameter F test:         F=4.8031  , p=0.0000  , df_denom=1911, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=4.6616  , p=0.0000  , df_denom=1908, df_num=30
# ssr based chi2 test:   chi2=144.3186, p=0.0000  , df=30
# likelihood ratio test: chi2=139.2747, p=0.0000  , df=30
# parameter F test:         F=4.6616  , p=0.0000  , df_denom=1908, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=4.6886  , p=0.0000  , df_denom=1905, df_num=31
# ssr based chi2 test:   chi2=150.1521, p=0.0000  , df=31
# likelihood ratio test: chi2=144.6997, p=0.0000  , df=31
# parameter F test:         F=4.6886  , p=0.0000  , df_denom=1905, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=4.7801  , p=0.0000  , df_denom=1902, df_num=32
# ssr based chi2 test:   chi2=158.1908, p=0.0000  , df=32
# likelihood ratio test: chi2=152.1514, p=0.0000  , df=32
# parameter F test:         F=4.7801  , p=0.0000  , df_denom=1902, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=4.6857  , p=0.0000  , df_denom=1899, df_num=33
# ssr based chi2 test:   chi2=160.0852, p=0.0000  , df=33
# likelihood ratio test: chi2=153.9011, p=0.0000  , df=33
# parameter F test:         F=4.6857  , p=0.0000  , df_denom=1899, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=4.5979  , p=0.0000  , df_denom=1896, df_num=34
# ssr based chi2 test:   chi2=162.0191, p=0.0000  , df=34
# likelihood ratio test: chi2=155.6855, p=0.0000  , df=34
# parameter F test:         F=4.5979  , p=0.0000  , df_denom=1896, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=4.5615  , p=0.0000  , df_denom=1893, df_num=35
# ssr based chi2 test:   chi2=165.6389, p=0.0000  , df=35
# likelihood ratio test: chi2=159.0236, p=0.0000  , df=35
# parameter F test:         F=4.5615  , p=0.0000  , df_denom=1893, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=4.4150  , p=0.0000  , df_denom=1890, df_num=36
# ssr based chi2 test:   chi2=165.0801, p=0.0000  , df=36
# likelihood ratio test: chi2=158.5050, p=0.0000  , df=36
# parameter F test:         F=4.4150  , p=0.0000  , df_denom=1890, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=4.3244  , p=0.0000  , df_denom=1887, df_num=37
# ssr based chi2 test:   chi2=166.3607, p=0.0000  , df=37
# likelihood ratio test: chi2=159.6826, p=0.0000  , df=37
# parameter F test:         F=4.3244  , p=0.0000  , df_denom=1887, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=4.2316  , p=0.0000  , df_denom=1884, df_num=38
# ssr based chi2 test:   chi2=167.3741, p=0.0000  , df=38
# likelihood ratio test: chi2=160.6134, p=0.0000  , df=38
# parameter F test:         F=4.2316  , p=0.0000  , df_denom=1884, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=4.1944  , p=0.0000  , df_denom=1881, df_num=39
# ssr based chi2 test:   chi2=170.4504, p=0.0000  , df=39
# likelihood ratio test: chi2=163.4423, p=0.0000  , df=39
# parameter F test:         F=4.1944  , p=0.0000  , df_denom=1881, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=4.0195  , p=0.0000  , df_denom=1878, df_num=40
# ssr based chi2 test:   chi2=167.7139, p=0.0000  , df=40
# likelihood ratio test: chi2=160.9199, p=0.0000  , df=40
# parameter F test:         F=4.0195  , p=0.0000  , df_denom=1878, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=3.9536  , p=0.0000  , df_denom=1875, df_num=41
# ssr based chi2 test:   chi2=169.2726, p=0.0000  , df=41
# likelihood ratio test: chi2=162.3518, p=0.0000  , df=41
# parameter F test:         F=3.9536  , p=0.0000  , df_denom=1875, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=3.8318  , p=0.0000  , df_denom=1872, df_num=42
# ssr based chi2 test:   chi2=168.2434, p=0.0000  , df=42
# likelihood ratio test: chi2=161.4010, p=0.0000  , df=42
# parameter F test:         F=3.8318  , p=0.0000  , df_denom=1872, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=3.7082  , p=0.0000  , df_denom=1869, df_num=43
# ssr based chi2 test:   chi2=166.8771, p=0.0000  , df=43
# likelihood ratio test: chi2=160.1391, p=0.0000  , df=43
# parameter F test:         F=3.7082  , p=0.0000  , df_denom=1869, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=3.7932  , p=0.0000  , df_denom=1866, df_num=44
# ssr based chi2 test:   chi2=174.8622, p=0.0000  , df=44
# likelihood ratio test: chi2=167.4792, p=0.0000  , df=44
# parameter F test:         F=3.7932  , p=0.0000  , df_denom=1866, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=3.6731  , p=0.0000  , df_denom=1863, df_num=45
# ssr based chi2 test:   chi2=173.3645, p=0.0000  , df=45
# likelihood ratio test: chi2=166.1005, p=0.0000  , df=45
# parameter F test:         F=3.6731  , p=0.0000  , df_denom=1863, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=3.8035  , p=0.0000  , df_denom=1860, df_num=46
# ssr based chi2 test:   chi2=183.7068, p=0.0000  , df=46
# likelihood ratio test: chi2=175.5730, p=0.0000  , df=46
# parameter F test:         F=3.8035  , p=0.0000  , df_denom=1860, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=3.9421  , p=0.0000  , df_denom=1857, df_num=47
# ssr based chi2 test:   chi2=194.7591, p=0.0000  , df=47
# likelihood ratio test: chi2=185.6446, p=0.0000  , df=47
# parameter F test:         F=3.9421  , p=0.0000  , df_denom=1857, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=3.8935  , p=0.0000  , df_denom=1854, df_num=48
# ssr based chi2 test:   chi2=196.6663, p=0.0000  , df=48
# likelihood ratio test: chi2=187.3735, p=0.0000  , df=48
# parameter F test:         F=3.8935  , p=0.0000  , df_denom=1854, df_num=48
# *******************************
#
#
# Series 1:  BTC_USD
# Series 2:  ETH_USD
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.6493  , p=0.1992  , df_denom=1995, df_num=1
# ssr based chi2 test:   chi2=1.6518  , p=0.1987  , df=1
# likelihood ratio test: chi2=1.6511  , p=0.1988  , df=1
# parameter F test:         F=1.6493  , p=0.1992  , df_denom=1995, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.5884  , p=0.0014  , df_denom=1992, df_num=2
# ssr based chi2 test:   chi2=13.2098 , p=0.0014  , df=2
# likelihood ratio test: chi2=13.1663 , p=0.0014  , df=2
# parameter F test:         F=6.5884  , p=0.0014  , df_denom=1992, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.5620  , p=0.0034  , df_denom=1989, df_num=3
# ssr based chi2 test:   chi2=13.7340 , p=0.0033  , df=3
# likelihood ratio test: chi2=13.6870 , p=0.0034  , df=3
# parameter F test:         F=4.5620  , p=0.0034  , df_denom=1989, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=6.3393  , p=0.0000  , df_denom=1986, df_num=4
# ssr based chi2 test:   chi2=25.4722 , p=0.0000  , df=4
# likelihood ratio test: chi2=25.3109 , p=0.0000  , df=4
# parameter F test:         F=6.3393  , p=0.0000  , df_denom=1986, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=6.4717  , p=0.0000  , df_denom=1983, df_num=5
# ssr based chi2 test:   chi2=32.5381 , p=0.0000  , df=5
# likelihood ratio test: chi2=32.2755 , p=0.0000  , df=5
# parameter F test:         F=6.4717  , p=0.0000  , df_denom=1983, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=5.2515  , p=0.0000  , df_denom=1980, df_num=6
# ssr based chi2 test:   chi2=31.7161 , p=0.0000  , df=6
# likelihood ratio test: chi2=31.4664 , p=0.0000  , df=6
# parameter F test:         F=5.2515  , p=0.0000  , df_denom=1980, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=6.4214  , p=0.0000  , df_denom=1977, df_num=7
# ssr based chi2 test:   chi2=45.2906 , p=0.0000  , df=7
# likelihood ratio test: chi2=44.7834 , p=0.0000  , df=7
# parameter F test:         F=6.4214  , p=0.0000  , df_denom=1977, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=8.3422  , p=0.0000  , df_denom=1974, df_num=8
# ssr based chi2 test:   chi2=67.3123 , p=0.0000  , df=8
# likelihood ratio test: chi2=66.1995 , p=0.0000  , df=8
# parameter F test:         F=8.3422  , p=0.0000  , df_denom=1974, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=8.0263  , p=0.0000  , df_denom=1971, df_num=9
# ssr based chi2 test:   chi2=72.9333 , p=0.0000  , df=9
# likelihood ratio test: chi2=71.6285 , p=0.0000  , df=9
# parameter F test:         F=8.0263  , p=0.0000  , df_denom=1971, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=7.3687  , p=0.0000  , df_denom=1968, df_num=10
# ssr based chi2 test:   chi2=74.4731 , p=0.0000  , df=10
# likelihood ratio test: chi2=73.1128 , p=0.0000  , df=10
# parameter F test:         F=7.3687  , p=0.0000  , df_denom=1968, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=7.5977  , p=0.0000  , df_denom=1965, df_num=11
# ssr based chi2 test:   chi2=84.5534 , p=0.0000  , df=11
# likelihood ratio test: chi2=82.8047 , p=0.0000  , df=11
# parameter F test:         F=7.5977  , p=0.0000  , df_denom=1965, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=8.8544  , p=0.0000  , df_denom=1962, df_num=12
# ssr based chi2 test:   chi2=107.6063, p=0.0000  , df=12
# likelihood ratio test: chi2=104.7937, p=0.0000  , df=12
# parameter F test:         F=8.8544  , p=0.0000  , df_denom=1962, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=9.3194  , p=0.0000  , df_denom=1959, df_num=13
# ssr based chi2 test:   chi2=122.8215, p=0.0000  , df=13
# likelihood ratio test: chi2=119.1733, p=0.0000  , df=13
# parameter F test:         F=9.3194  , p=0.0000  , df_denom=1959, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=8.5320  , p=0.0000  , df_denom=1956, df_num=14
# ssr based chi2 test:   chi2=121.2193, p=0.0000  , df=14
# likelihood ratio test: chi2=117.6621, p=0.0000  , df=14
# parameter F test:         F=8.5320  , p=0.0000  , df_denom=1956, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=7.9904  , p=0.0000  , df_denom=1953, df_num=15
# ssr based chi2 test:   chi2=121.7582, p=0.0000  , df=15
# likelihood ratio test: chi2=118.1682, p=0.0000  , df=15
# parameter F test:         F=7.9904  , p=0.0000  , df_denom=1953, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=7.6324  , p=0.0000  , df_denom=1950, df_num=16
# ssr based chi2 test:   chi2=124.1855, p=0.0000  , df=16
# likelihood ratio test: chi2=120.4520, p=0.0000  , df=16
# parameter F test:         F=7.6324  , p=0.0000  , df_denom=1950, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=7.1689  , p=0.0000  , df_denom=1947, df_num=17
# ssr based chi2 test:   chi2=124.0623, p=0.0000  , df=17
# likelihood ratio test: chi2=120.3343, p=0.0000  , df=17
# parameter F test:         F=7.1689  , p=0.0000  , df_denom=1947, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=7.1315  , p=0.0000  , df_denom=1944, df_num=18
# ssr based chi2 test:   chi2=130.8098, p=0.0000  , df=18
# likelihood ratio test: chi2=126.6722, p=0.0000  , df=18
# parameter F test:         F=7.1315  , p=0.0000  , df_denom=1944, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=6.5938  , p=0.0000  , df_denom=1941, df_num=19
# ssr based chi2 test:   chi2=127.7996, p=0.0000  , df=19
# likelihood ratio test: chi2=123.8445, p=0.0000  , df=19
# parameter F test:         F=6.5938  , p=0.0000  , df_denom=1941, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=6.2851  , p=0.0000  , df_denom=1938, df_num=20
# ssr based chi2 test:   chi2=128.3616, p=0.0000  , df=20
# likelihood ratio test: chi2=124.3704, p=0.0000  , df=20
# parameter F test:         F=6.2851  , p=0.0000  , df_denom=1938, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=5.9958  , p=0.0000  , df_denom=1935, df_num=21
# ssr based chi2 test:   chi2=128.7096, p=0.0000  , df=21
# likelihood ratio test: chi2=124.6953, p=0.0000  , df=21
# parameter F test:         F=5.9958  , p=0.0000  , df_denom=1935, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=5.7342  , p=0.0000  , df_denom=1932, df_num=22
# ssr based chi2 test:   chi2=129.0899, p=0.0000  , df=22
# likelihood ratio test: chi2=125.0503, p=0.0000  , df=22
# parameter F test:         F=5.7342  , p=0.0000  , df_denom=1932, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=5.8173  , p=0.0000  , df_denom=1929, df_num=23
# ssr based chi2 test:   chi2=137.0575, p=0.0000  , df=23
# likelihood ratio test: chi2=132.5133, p=0.0000  , df=23
# parameter F test:         F=5.8173  , p=0.0000  , df_denom=1929, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=5.5192  , p=0.0000  , df_denom=1926, df_num=24
# ssr based chi2 test:   chi2=135.8303, p=0.0000  , df=24
# likelihood ratio test: chi2=131.3631, p=0.0000  , df=24
# parameter F test:         F=5.5192  , p=0.0000  , df_denom=1926, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=5.6523  , p=0.0000  , df_denom=1923, df_num=25
# ssr based chi2 test:   chi2=145.0550, p=0.0000  , df=25
# likelihood ratio test: chi2=139.9730, p=0.0000  , df=25
# parameter F test:         F=5.6523  , p=0.0000  , df_denom=1923, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=5.5161  , p=0.0000  , df_denom=1920, df_num=26
# ssr based chi2 test:   chi2=147.3763, p=0.0000  , df=26
# likelihood ratio test: chi2=142.1317, p=0.0000  , df=26
# parameter F test:         F=5.5161  , p=0.0000  , df_denom=1920, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=5.1884  , p=0.0000  , df_denom=1917, df_num=27
# ssr based chi2 test:   chi2=144.1058, p=0.0000  , df=27
# likelihood ratio test: chi2=139.0837, p=0.0000  , df=27
# parameter F test:         F=5.1884  , p=0.0000  , df_denom=1917, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=4.9930  , p=0.0000  , df_denom=1914, df_num=28
# ssr based chi2 test:   chi2=143.9677, p=0.0000  , df=28
# likelihood ratio test: chi2=138.9525, p=0.0000  , df=28
# parameter F test:         F=4.9930  , p=0.0000  , df_denom=1914, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=4.9130  , p=0.0000  , df_denom=1911, df_num=29
# ssr based chi2 test:   chi2=146.8771, p=0.0000  , df=29
# likelihood ratio test: chi2=141.6595, p=0.0000  , df=29
# parameter F test:         F=4.9130  , p=0.0000  , df_denom=1911, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=4.9518  , p=0.0000  , df_denom=1908, df_num=30
# ssr based chi2 test:   chi2=153.3025, p=0.0000  , df=30
# likelihood ratio test: chi2=147.6273, p=0.0000  , df=30
# parameter F test:         F=4.9518  , p=0.0000  , df_denom=1908, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=5.0382  , p=0.0000  , df_denom=1905, df_num=31
# ssr based chi2 test:   chi2=161.3484, p=0.0000  , df=31
# likelihood ratio test: chi2=155.0749, p=0.0000  , df=31
# parameter F test:         F=5.0382  , p=0.0000  , df_denom=1905, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=5.0900  , p=0.0000  , df_denom=1902, df_num=32
# ssr based chi2 test:   chi2=168.4478, p=0.0000  , df=32
# likelihood ratio test: chi2=161.6221, p=0.0000  , df=32
# parameter F test:         F=5.0900  , p=0.0000  , df_denom=1902, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=5.0800  , p=0.0000  , df_denom=1899, df_num=33
# ssr based chi2 test:   chi2=173.5541, p=0.0000  , df=33
# likelihood ratio test: chi2=166.3166, p=0.0000  , df=33
# parameter F test:         F=5.0800  , p=0.0000  , df_denom=1899, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=5.0251  , p=0.0000  , df_denom=1896, df_num=34
# ssr based chi2 test:   chi2=177.0729, p=0.0000  , df=34
# likelihood ratio test: chi2=169.5437, p=0.0000  , df=34
# parameter F test:         F=5.0251  , p=0.0000  , df_denom=1896, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=4.9180  , p=0.0000  , df_denom=1893, df_num=35
# ssr based chi2 test:   chi2=178.5854, p=0.0000  , df=35
# likelihood ratio test: chi2=170.9270, p=0.0000  , df=35
# parameter F test:         F=4.9180  , p=0.0000  , df_denom=1893, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=4.8111  , p=0.0000  , df_denom=1890, df_num=36
# ssr based chi2 test:   chi2=179.8905, p=0.0000  , df=36
# likelihood ratio test: chi2=172.1191, p=0.0000  , df=36
# parameter F test:         F=4.8111  , p=0.0000  , df_denom=1890, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=4.7591  , p=0.0000  , df_denom=1887, df_num=37
# ssr based chi2 test:   chi2=183.0852, p=0.0000  , df=37
# likelihood ratio test: chi2=175.0396, p=0.0000  , df=37
# parameter F test:         F=4.7591  , p=0.0000  , df_denom=1887, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=4.6563  , p=0.0000  , df_denom=1884, df_num=38
# ssr based chi2 test:   chi2=184.1700, p=0.0000  , df=38
# likelihood ratio test: chi2=176.0277, p=0.0000  , df=38
# parameter F test:         F=4.6563  , p=0.0000  , df_denom=1884, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=4.5520  , p=0.0000  , df_denom=1881, df_num=39
# ssr based chi2 test:   chi2=184.9859, p=0.0000  , df=39
# likelihood ratio test: chi2=176.7695, p=0.0000  , df=39
# parameter F test:         F=4.5520  , p=0.0000  , df_denom=1881, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=4.3925  , p=0.0000  , df_denom=1878, df_num=40
# ssr based chi2 test:   chi2=183.2791, p=0.0000  , df=40
# likelihood ratio test: chi2=175.2053, p=0.0000  , df=40
# parameter F test:         F=4.3925  , p=0.0000  , df_denom=1878, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=4.3247  , p=0.0000  , df_denom=1875, df_num=41
# ssr based chi2 test:   chi2=185.1636, p=0.0000  , df=41
# likelihood ratio test: chi2=176.9239, p=0.0000  , df=41
# parameter F test:         F=4.3247  , p=0.0000  , df_denom=1875, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=4.2235  , p=0.0000  , df_denom=1872, df_num=42
# ssr based chi2 test:   chi2=185.4434, p=0.0000  , df=42
# likelihood ratio test: chi2=177.1756, p=0.0000  , df=42
# parameter F test:         F=4.2235  , p=0.0000  , df_denom=1872, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=4.4152  , p=0.0000  , df_denom=1869, df_num=43
# ssr based chi2 test:   chi2=198.6926, p=0.0000  , df=43
# likelihood ratio test: chi2=189.2361, p=0.0000  , df=43
# parameter F test:         F=4.4152  , p=0.0000  , df_denom=1869, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=4.3077  , p=0.0000  , df_denom=1866, df_num=44
# ssr based chi2 test:   chi2=198.5800, p=0.0000  , df=44
# likelihood ratio test: chi2=189.1294, p=0.0000  , df=44
# parameter F test:         F=4.3077  , p=0.0000  , df_denom=1866, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=4.2803  , p=0.0000  , df_denom=1863, df_num=45
# ssr based chi2 test:   chi2=202.0238, p=0.0000  , df=45
# likelihood ratio test: chi2=192.2484, p=0.0000  , df=45
# parameter F test:         F=4.2803  , p=0.0000  , df_denom=1863, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=4.1879  , p=0.0000  , df_denom=1860, df_num=46
# ssr based chi2 test:   chi2=202.2756, p=0.0000  , df=46
# likelihood ratio test: chi2=192.4720, p=0.0000  , df=46
# parameter F test:         F=4.1879  , p=0.0000  , df_denom=1860, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=4.1293  , p=0.0000  , df_denom=1857, df_num=47
# ssr based chi2 test:   chi2=204.0040, p=0.0000  , df=47
# likelihood ratio test: chi2=194.0327, p=0.0000  , df=47
# parameter F test:         F=4.1293  , p=0.0000  , df_denom=1857, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=4.0622  , p=0.0000  , df_denom=1854, df_num=48
# ssr based chi2 test:   chi2=205.1883, p=0.0000  , df=48
# likelihood ratio test: chi2=195.0999, p=0.0000  , df=48
# parameter F test:         F=4.0622  , p=0.0000  , df_denom=1854, df_num=48
# *******************************
#
#
# Series 1:  BTC_USD
# Series 2:  LTC_USD
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.9432  , p=0.0864  , df_denom=1995, df_num=1
# ssr based chi2 test:   chi2=2.9476  , p=0.0860  , df=1
# likelihood ratio test: chi2=2.9455  , p=0.0861  , df=1
# parameter F test:         F=2.9432  , p=0.0864  , df_denom=1995, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.0040  , p=0.0184  , df_denom=1992, df_num=2
# ssr based chi2 test:   chi2=8.0280  , p=0.0181  , df=2
# likelihood ratio test: chi2=8.0119  , p=0.0182  , df=2
# parameter F test:         F=4.0040  , p=0.0184  , df_denom=1992, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.1274  , p=0.0248  , df_denom=1989, df_num=3
# ssr based chi2 test:   chi2=9.4153  , p=0.0242  , df=3
# likelihood ratio test: chi2=9.3932  , p=0.0245  , df=3
# parameter F test:         F=3.1274  , p=0.0248  , df_denom=1989, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.6092  , p=0.0340  , df_denom=1986, df_num=4
# ssr based chi2 test:   chi2=10.4841 , p=0.0330  , df=4
# likelihood ratio test: chi2=10.4566 , p=0.0334  , df=4
# parameter F test:         F=2.6092  , p=0.0340  , df_denom=1986, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.6132  , p=0.0231  , df_denom=1983, df_num=5
# ssr based chi2 test:   chi2=13.1384 , p=0.0221  , df=5
# likelihood ratio test: chi2=13.0953 , p=0.0225  , df=5
# parameter F test:         F=2.6132  , p=0.0231  , df_denom=1983, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.9221  , p=0.0738  , df_denom=1980, df_num=6
# ssr based chi2 test:   chi2=11.6083 , p=0.0713  , df=6
# likelihood ratio test: chi2=11.5746 , p=0.0722  , df=6
# parameter F test:         F=1.9221  , p=0.0738  , df_denom=1980, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6469  , p=0.1179  , df_denom=1977, df_num=7
# ssr based chi2 test:   chi2=11.6157 , p=0.1139  , df=7
# likelihood ratio test: chi2=11.5819 , p=0.1152  , df=7
# parameter F test:         F=1.6469  , p=0.1179  , df_denom=1977, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=6.1472  , p=0.0000  , df_denom=1974, df_num=8
# ssr based chi2 test:   chi2=49.6014 , p=0.0000  , df=8
# likelihood ratio test: chi2=48.9936 , p=0.0000  , df=8
# parameter F test:         F=6.1472  , p=0.0000  , df_denom=1974, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=8.3706  , p=0.0000  , df_denom=1971, df_num=9
# ssr based chi2 test:   chi2=76.0612 , p=0.0000  , df=9
# likelihood ratio test: chi2=74.6436 , p=0.0000  , df=9
# parameter F test:         F=8.3706  , p=0.0000  , df_denom=1971, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=7.7019  , p=0.0000  , df_denom=1968, df_num=10
# ssr based chi2 test:   chi2=77.8413 , p=0.0000  , df=10
# likelihood ratio test: chi2=76.3567 , p=0.0000  , df=10
# parameter F test:         F=7.7019  , p=0.0000  , df_denom=1968, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=9.1526  , p=0.0000  , df_denom=1965, df_num=11
# ssr based chi2 test:   chi2=101.8576, p=0.0000  , df=11
# likelihood ratio test: chi2=99.3340 , p=0.0000  , df=11
# parameter F test:         F=9.1526  , p=0.0000  , df_denom=1965, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=9.1843  , p=0.0000  , df_denom=1962, df_num=12
# ssr based chi2 test:   chi2=111.6162, p=0.0000  , df=12
# likelihood ratio test: chi2=108.5939, p=0.0000  , df=12
# parameter F test:         F=9.1843  , p=0.0000  , df_denom=1962, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=8.9715  , p=0.0000  , df_denom=1959, df_num=13
# ssr based chi2 test:   chi2=118.2367, p=0.0000  , df=13
# likelihood ratio test: chi2=114.8508, p=0.0000  , df=13
# parameter F test:         F=8.9715  , p=0.0000  , df_denom=1959, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=8.4218  , p=0.0000  , df_denom=1956, df_num=14
# ssr based chi2 test:   chi2=119.6529, p=0.0000  , df=14
# likelihood ratio test: chi2=116.1853, p=0.0000  , df=14
# parameter F test:         F=8.4218  , p=0.0000  , df_denom=1956, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=8.1743  , p=0.0000  , df_denom=1953, df_num=15
# ssr based chi2 test:   chi2=124.5612, p=0.0000  , df=15
# likelihood ratio test: chi2=120.8074, p=0.0000  , df=15
# parameter F test:         F=8.1743  , p=0.0000  , df_denom=1953, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=7.9687  , p=0.0000  , df_denom=1950, df_num=16
# ssr based chi2 test:   chi2=129.6574, p=0.0000  , df=16
# likelihood ratio test: chi2=125.5947, p=0.0000  , df=16
# parameter F test:         F=7.9687  , p=0.0000  , df_denom=1950, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=7.4719  , p=0.0000  , df_denom=1947, df_num=17
# ssr based chi2 test:   chi2=129.3060, p=0.0000  , df=17
# likelihood ratio test: chi2=125.2630, p=0.0000  , df=17
# parameter F test:         F=7.4719  , p=0.0000  , df_denom=1947, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=7.0997  , p=0.0000  , df_denom=1944, df_num=18
# ssr based chi2 test:   chi2=130.2274, p=0.0000  , df=18
# likelihood ratio test: chi2=126.1258, p=0.0000  , df=18
# parameter F test:         F=7.0997  , p=0.0000  , df_denom=1944, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=6.9390  , p=0.0000  , df_denom=1941, df_num=19
# ssr based chi2 test:   chi2=134.4908, p=0.0000  , df=19
# likelihood ratio test: chi2=130.1200, p=0.0000  , df=19
# parameter F test:         F=6.9390  , p=0.0000  , df_denom=1941, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=6.7099  , p=0.0000  , df_denom=1938, df_num=20
# ssr based chi2 test:   chi2=137.0378, p=0.0000  , df=20
# likelihood ratio test: chi2=132.5014, p=0.0000  , df=20
# parameter F test:         F=6.7099  , p=0.0000  , df_denom=1938, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=6.2470  , p=0.0000  , df_denom=1935, df_num=21
# ssr based chi2 test:   chi2=134.1033, p=0.0000  , df=21
# likelihood ratio test: chi2=129.7530, p=0.0000  , df=21
# parameter F test:         F=6.2470  , p=0.0000  , df_denom=1935, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=6.1234  , p=0.0000  , df_denom=1932, df_num=22
# ssr based chi2 test:   chi2=137.8530, p=0.0000  , df=22
# likelihood ratio test: chi2=133.2592, p=0.0000  , df=22
# parameter F test:         F=6.1234  , p=0.0000  , df_denom=1932, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=6.1088  , p=0.0000  , df_denom=1929, df_num=23
# ssr based chi2 test:   chi2=143.9247, p=0.0000  , df=23
# likelihood ratio test: chi2=138.9246, p=0.0000  , df=23
# parameter F test:         F=6.1088  , p=0.0000  , df_denom=1929, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=5.7874  , p=0.0000  , df_denom=1926, df_num=24
# ssr based chi2 test:   chi2=142.4325, p=0.0000  , df=24
# likelihood ratio test: chi2=137.5308, p=0.0000  , df=24
# parameter F test:         F=5.7874  , p=0.0000  , df_denom=1926, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=6.0547  , p=0.0000  , df_denom=1923, df_num=25
# ssr based chi2 test:   chi2=155.3828, p=0.0000  , df=25
# likelihood ratio test: chi2=149.5704, p=0.0000  , df=25
# parameter F test:         F=6.0547  , p=0.0000  , df_denom=1923, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=6.3100  , p=0.0000  , df_denom=1920, df_num=26
# ssr based chi2 test:   chi2=168.5897, p=0.0000  , df=26
# likelihood ratio test: chi2=161.7725, p=0.0000  , df=26
# parameter F test:         F=6.3100  , p=0.0000  , df_denom=1920, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=5.7362  , p=0.0000  , df_denom=1917, df_num=27
# ssr based chi2 test:   chi2=159.3201, p=0.0000  , df=27
# likelihood ratio test: chi2=153.2112, p=0.0000  , df=27
# parameter F test:         F=5.7362  , p=0.0000  , df_denom=1917, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=5.5876  , p=0.0000  , df_denom=1914, df_num=28
# ssr based chi2 test:   chi2=161.1129, p=0.0000  , df=28
# likelihood ratio test: chi2=154.8663, p=0.0000  , df=28
# parameter F test:         F=5.5876  , p=0.0000  , df_denom=1914, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=5.5280  , p=0.0000  , df_denom=1911, df_num=29
# ssr based chi2 test:   chi2=165.2604, p=0.0000  , df=29
# likelihood ratio test: chi2=158.6934, p=0.0000  , df=29
# parameter F test:         F=5.5280  , p=0.0000  , df_denom=1911, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=5.3946  , p=0.0000  , df_denom=1908, df_num=30
# ssr based chi2 test:   chi2=167.0134, p=0.0000  , df=30
# likelihood ratio test: chi2=160.3069, p=0.0000  , df=30
# parameter F test:         F=5.3946  , p=0.0000  , df_denom=1908, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=5.2276  , p=0.0000  , df_denom=1905, df_num=31
# ssr based chi2 test:   chi2=167.4152, p=0.0000  , df=31
# likelihood ratio test: chi2=160.6740, p=0.0000  , df=31
# parameter F test:         F=5.2276  , p=0.0000  , df_denom=1905, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=5.0153  , p=0.0000  , df_denom=1902, df_num=32
# ssr based chi2 test:   chi2=165.9737, p=0.0000  , df=32
# likelihood ratio test: chi2=159.3419, p=0.0000  , df=32
# parameter F test:         F=5.0153  , p=0.0000  , df_denom=1902, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=4.9724  , p=0.0000  , df_denom=1899, df_num=33
# ssr based chi2 test:   chi2=169.8777, p=0.0000  , df=33
# likelihood ratio test: chi2=162.9355, p=0.0000  , df=33
# parameter F test:         F=4.9724  , p=0.0000  , df_denom=1899, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=5.2829  , p=0.0000  , df_denom=1896, df_num=34
# ssr based chi2 test:   chi2=186.1552, p=0.0000  , df=34
# likelihood ratio test: chi2=177.8576, p=0.0000  , df=34
# parameter F test:         F=5.2829  , p=0.0000  , df_denom=1896, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=5.1963  , p=0.0000  , df_denom=1893, df_num=35
# ssr based chi2 test:   chi2=188.6933, p=0.0000  , df=35
# likelihood ratio test: chi2=180.1706, p=0.0000  , df=35
# parameter F test:         F=5.1963  , p=0.0000  , df_denom=1893, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=4.9741  , p=0.0000  , df_denom=1890, df_num=36
# ssr based chi2 test:   chi2=185.9827, p=0.0000  , df=36
# likelihood ratio test: chi2=177.6920, p=0.0000  , df=36
# parameter F test:         F=4.9741  , p=0.0000  , df_denom=1890, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=4.8600  , p=0.0000  , df_denom=1887, df_num=37
# ssr based chi2 test:   chi2=186.9681, p=0.0000  , df=37
# likelihood ratio test: chi2=178.5879, p=0.0000  , df=37
# parameter F test:         F=4.8600  , p=0.0000  , df_denom=1887, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=4.8454  , p=0.0000  , df_denom=1884, df_num=38
# ssr based chi2 test:   chi2=191.6505, p=0.0000  , df=38
# likelihood ratio test: chi2=182.8541, p=0.0000  , df=38
# parameter F test:         F=4.8454  , p=0.0000  , df_denom=1884, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=4.7601  , p=0.0000  , df_denom=1881, df_num=39
# ssr based chi2 test:   chi2=193.4406, p=0.0000  , df=39
# likelihood ratio test: chi2=184.4798, p=0.0000  , df=39
# parameter F test:         F=4.7601  , p=0.0000  , df_denom=1881, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=4.5236  , p=0.0000  , df_denom=1878, df_num=40
# ssr based chi2 test:   chi2=188.7474, p=0.0000  , df=40
# likelihood ratio test: chi2=180.1995, p=0.0000  , df=40
# parameter F test:         F=4.5236  , p=0.0000  , df_denom=1878, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=4.4940  , p=0.0000  , df_denom=1875, df_num=41
# ssr based chi2 test:   chi2=192.4082, p=0.0000  , df=41
# likelihood ratio test: chi2=183.5314, p=0.0000  , df=41
# parameter F test:         F=4.4940  , p=0.0000  , df_denom=1875, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=4.3274  , p=0.0000  , df_denom=1872, df_num=42
# ssr based chi2 test:   chi2=190.0031, p=0.0000  , df=42
# likelihood ratio test: chi2=181.3362, p=0.0000  , df=42
# parameter F test:         F=4.3274  , p=0.0000  , df_denom=1872, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=4.1623  , p=0.0000  , df_denom=1869, df_num=43
# ssr based chi2 test:   chi2=187.3083, p=0.0000  , df=43
# likelihood ratio test: chi2=178.8743, p=0.0000  , df=43
# parameter F test:         F=4.1623  , p=0.0000  , df_denom=1869, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=4.1011  , p=0.0000  , df_denom=1866, df_num=44
# ssr based chi2 test:   chi2=189.0537, p=0.0000  , df=44
# likelihood ratio test: chi2=180.4623, p=0.0000  , df=44
# parameter F test:         F=4.1011  , p=0.0000  , df_denom=1866, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=4.1031  , p=0.0000  , df_denom=1863, df_num=45
# ssr based chi2 test:   chi2=193.6575, p=0.0000  , df=45
# likelihood ratio test: chi2=184.6513, p=0.0000  , df=45
# parameter F test:         F=4.1031  , p=0.0000  , df_denom=1863, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=4.0530  , p=0.0000  , df_denom=1860, df_num=46
# ssr based chi2 test:   chi2=195.7612, p=0.0000  , df=46
# likelihood ratio test: chi2=186.5600, p=0.0000  , df=46
# parameter F test:         F=4.0530  , p=0.0000  , df_denom=1860, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=4.0120  , p=0.0000  , df_denom=1857, df_num=47
# ssr based chi2 test:   chi2=198.2106, p=0.0000  , df=47
# likelihood ratio test: chi2=188.7804, p=0.0000  , df=47
# parameter F test:         F=4.0120  , p=0.0000  , df_denom=1857, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=4.0211  , p=0.0000  , df_denom=1854, df_num=48
# ssr based chi2 test:   chi2=203.1095, p=0.0000  , df=48
# likelihood ratio test: chi2=193.2180, p=0.0000  , df=48
# parameter F test:         F=4.0211  , p=0.0000  , df_denom=1854, df_num=48
# *******************************
#
#
# Series 1:  BTC_USD
# Series 2:  XMR_USD
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1652  , p=0.6845  , df_denom=1995, df_num=1
# ssr based chi2 test:   chi2=0.1655  , p=0.6842  , df=1
# likelihood ratio test: chi2=0.1654  , p=0.6842  , df=1
# parameter F test:         F=0.1652  , p=0.6845  , df_denom=1995, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3209  , p=0.7256  , df_denom=1992, df_num=2
# ssr based chi2 test:   chi2=0.6433  , p=0.7249  , df=2
# likelihood ratio test: chi2=0.6432  , p=0.7250  , df=2
# parameter F test:         F=0.3209  , p=0.7256  , df_denom=1992, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2603  , p=0.2864  , df_denom=1989, df_num=3
# ssr based chi2 test:   chi2=3.7942  , p=0.2846  , df=3
# likelihood ratio test: chi2=3.7906  , p=0.2850  , df=3
# parameter F test:         F=1.2603  , p=0.2864  , df_denom=1989, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0556  , p=0.3770  , df_denom=1986, df_num=4
# ssr based chi2 test:   chi2=4.2415  , p=0.3743  , df=4
# likelihood ratio test: chi2=4.2370  , p=0.3749  , df=4
# parameter F test:         F=1.0556  , p=0.3770  , df_denom=1986, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.3592  , p=0.0381  , df_denom=1983, df_num=5
# ssr based chi2 test:   chi2=11.8616 , p=0.0367  , df=5
# likelihood ratio test: chi2=11.8264 , p=0.0372  , df=5
# parameter F test:         F=2.3592  , p=0.0381  , df_denom=1983, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.1917  , p=0.0412  , df_denom=1980, df_num=6
# ssr based chi2 test:   chi2=13.2366 , p=0.0394  , df=6
# likelihood ratio test: chi2=13.1929 , p=0.0401  , df=6
# parameter F test:         F=2.1917  , p=0.0412  , df_denom=1980, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.9871  , p=0.0040  , df_denom=1977, df_num=7
# ssr based chi2 test:   chi2=21.0682 , p=0.0037  , df=7
# likelihood ratio test: chi2=20.9576 , p=0.0038  , df=7
# parameter F test:         F=2.9871  , p=0.0040  , df_denom=1977, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=4.7741  , p=0.0000  , df_denom=1974, df_num=8
# ssr based chi2 test:   chi2=38.5214 , p=0.0000  , df=8
# likelihood ratio test: chi2=38.1535 , p=0.0000  , df=8
# parameter F test:         F=4.7741  , p=0.0000  , df_denom=1974, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=5.0939  , p=0.0000  , df_denom=1971, df_num=9
# ssr based chi2 test:   chi2=46.2871 , p=0.0000  , df=9
# likelihood ratio test: chi2=45.7570 , p=0.0000  , df=9
# parameter F test:         F=5.0939  , p=0.0000  , df_denom=1971, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=5.2544  , p=0.0000  , df_denom=1968, df_num=10
# ssr based chi2 test:   chi2=53.1048 , p=0.0000  , df=10
# likelihood ratio test: chi2=52.4083 , p=0.0000  , df=10
# parameter F test:         F=5.2544  , p=0.0000  , df_denom=1968, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=6.5151  , p=0.0000  , df_denom=1965, df_num=11
# ssr based chi2 test:   chi2=72.5048 , p=0.0000  , df=11
# likelihood ratio test: chi2=71.2139 , p=0.0000  , df=11
# parameter F test:         F=6.5151  , p=0.0000  , df_denom=1965, df_num=11
#
# Granger Causality
# ...
# likelihood ratio test: chi2=80.3578 , p=0.0009  , df=45
# parameter F test:         F=1.7381  , p=0.0019  , df_denom=1863, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.7004  , p=0.0025  , df_denom=1860, df_num=46
# ssr based chi2 test:   chi2=82.1290 , p=0.0008  , df=46
# likelihood ratio test: chi2=80.4490 , p=0.0013  , df=46
# parameter F test:         F=1.7004  , p=0.0025  , df_denom=1860, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.6707  , p=0.0031  , df_denom=1857, df_num=47
# ssr based chi2 test:   chi2=82.5388 , p=0.0010  , df=47
# likelihood ratio test: chi2=80.8415 , p=0.0016  , df=47
# parameter F test:         F=1.6707  , p=0.0031  , df_denom=1857, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=1.6345  , p=0.0042  , df_denom=1854, df_num=48
# ssr based chi2 test:   chi2=82.5603 , p=0.0014  , df=48
# likelihood ratio test: chi2=80.8612 , p=0.0021  , df=48
# parameter F test:         F=1.6345  , p=0.0042  , df_denom=1854, df_num=48
# *******************************
#
#
# Series 1:  XMR_USD
# Series 2:  LTC_USD
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=29.5520 , p=0.0000  , df_denom=1995, df_num=1
# ssr based chi2 test:   chi2=29.5965 , p=0.0000  , df=1
# likelihood ratio test: chi2=29.3794 , p=0.0000  , df=1
# parameter F test:         F=29.5520 , p=0.0000  , df_denom=1995, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=15.9296 , p=0.0000  , df_denom=1992, df_num=2
# ssr based chi2 test:   chi2=31.9391 , p=0.0000  , df=2
# likelihood ratio test: chi2=31.6864 , p=0.0000  , df=2
# parameter F test:         F=15.9296 , p=0.0000  , df_denom=1992, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=11.1876 , p=0.0000  , df_denom=1989, df_num=3
# ssr based chi2 test:   chi2=33.6810 , p=0.0000  , df=3
# likelihood ratio test: chi2=33.4000 , p=0.0000  , df=3
# parameter F test:         F=11.1876 , p=0.0000  , df_denom=1989, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=10.9924 , p=0.0000  , df_denom=1986, df_num=4
# ssr based chi2 test:   chi2=44.1689 , p=0.0000  , df=4
# likelihood ratio test: chi2=43.6871 , p=0.0000  , df=4
# parameter F test:         F=10.9924 , p=0.0000  , df_denom=1986, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=9.0000  , p=0.0000  , df_denom=1983, df_num=5
# ssr based chi2 test:   chi2=45.2498 , p=0.0000  , df=5
# likelihood ratio test: chi2=44.7440 , p=0.0000  , df=5
# parameter F test:         F=9.0000  , p=0.0000  , df_denom=1983, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=8.3930  , p=0.0000  , df_denom=1980, df_num=6
# ssr based chi2 test:   chi2=50.6887 , p=0.0000  , df=6
# likelihood ratio test: chi2=50.0548 , p=0.0000  , df=6
# parameter F test:         F=8.3930  , p=0.0000  , df_denom=1980, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=7.4868  , p=0.0000  , df_denom=1977, df_num=7
# ssr based chi2 test:   chi2=52.8051 , p=0.0000  , df=7
# likelihood ratio test: chi2=52.1173 , p=0.0000  , df=7
# parameter F test:         F=7.4868  , p=0.0000  , df_denom=1977, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=6.6670  , p=0.0000  , df_denom=1974, df_num=8
# ssr based chi2 test:   chi2=53.7950 , p=0.0000  , df=8
# likelihood ratio test: chi2=53.0811 , p=0.0000  , df=8
# parameter F test:         F=6.6670  , p=0.0000  , df_denom=1974, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=6.6827  , p=0.0000  , df_denom=1971, df_num=9
# ssr based chi2 test:   chi2=60.7241 , p=0.0000  , df=9
# likelihood ratio test: chi2=59.8160 , p=0.0000  , df=9
# parameter F test:         F=6.6827  , p=0.0000  , df_denom=1971, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=8.2085  , p=0.0000  , df_denom=1968, df_num=10
# ssr based chi2 test:   chi2=82.9612 , p=0.0000  , df=10
# likelihood ratio test: chi2=81.2777 , p=0.0000  , df=10
# parameter F test:         F=8.2085  , p=0.0000  , df_denom=1968, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=7.7711  , p=0.0000  , df_denom=1965, df_num=11
# ssr based chi2 test:   chi2=86.4829 , p=0.0000  , df=11
# likelihood ratio test: chi2=84.6546 , p=0.0000  , df=11
# parameter F test:         F=7.7711  , p=0.0000  , df_denom=1965, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=7.3147  , p=0.0000  , df_denom=1962, df_num=12
# ssr based chi2 test:   chi2=88.8948 , p=0.0000  , df=12
# likelihood ratio test: chi2=86.9637 , p=0.0000  , df=12
# parameter F test:         F=7.3147  , p=0.0000  , df_denom=1962, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=8.3815  , p=0.0000  , df_denom=1959, df_num=13
# ssr based chi2 test:   chi2=110.4607, p=0.0000  , df=13
# likelihood ratio test: chi2=107.4982, p=0.0000  , df=13
# parameter F test:         F=8.3815  , p=0.0000  , df_denom=1959, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=7.8207  , p=0.0000  , df_denom=1956, df_num=14
# ssr based chi2 test:   chi2=111.1136, p=0.0000  , df=14
# likelihood ratio test: chi2=108.1151, p=0.0000  , df=14
# parameter F test:         F=7.8207  , p=0.0000  , df_denom=1956, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=7.3228  , p=0.0000  , df_denom=1953, df_num=15
# ssr based chi2 test:   chi2=111.5851, p=0.0000  , df=15
# likelihood ratio test: chi2=108.5601, p=0.0000  , df=15
# parameter F test:         F=7.3228  , p=0.0000  , df_denom=1953, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=6.8895  , p=0.0000  , df_denom=1950, df_num=16
# ssr based chi2 test:   chi2=112.0969, p=0.0000  , df=16
# likelihood ratio test: chi2=109.0431, p=0.0000  , df=16
# parameter F test:         F=6.8895  , p=0.0000  , df_denom=1950, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=6.4858  , p=0.0000  , df_denom=1947, df_num=17
# ssr based chi2 test:   chi2=112.2403, p=0.0000  , df=17
# likelihood ratio test: chi2=109.1773, p=0.0000  , df=17
# parameter F test:         F=6.4858  , p=0.0000  , df_denom=1947, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=6.0298  , p=0.0000  , df_denom=1944, df_num=18
# ssr based chi2 test:   chi2=110.6014, p=0.0000  , df=18
# likelihood ratio test: chi2=107.6242, p=0.0000  , df=18
# parameter F test:         F=6.0298  , p=0.0000  , df_denom=1944, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=5.7495  , p=0.0000  , df_denom=1941, df_num=19
# ssr based chi2 test:   chi2=111.4354, p=0.0000  , df=19
# likelihood ratio test: chi2=108.4125, p=0.0000  , df=19
# parameter F test:         F=5.7495  , p=0.0000  , df_denom=1941, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=5.6930  , p=0.0000  , df_denom=1938, df_num=20
# ssr based chi2 test:   chi2=116.2696, p=0.0000  , df=20
# likelihood ratio test: chi2=112.9822, p=0.0000  , df=20
# parameter F test:         F=5.6930  , p=0.0000  , df_denom=1938, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=5.3681  , p=0.0000  , df_denom=1935, df_num=21
# ssr based chi2 test:   chi2=115.2345, p=0.0000  , df=21
# likelihood ratio test: chi2=112.0027, p=0.0000  , df=21
# parameter F test:         F=5.3681  , p=0.0000  , df_denom=1935, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=5.2129  , p=0.0000  , df_denom=1932, df_num=22
# ssr based chi2 test:   chi2=117.3545, p=0.0000  , df=22
# likelihood ratio test: chi2=114.0034, p=0.0000  , df=22
# parameter F test:         F=5.2129  , p=0.0000  , df_denom=1932, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=5.0365  , p=0.0000  , df_denom=1929, df_num=23
# ssr based chi2 test:   chi2=118.6621, p=0.0000  , df=23
# likelihood ratio test: chi2=115.2357, p=0.0000  , df=23
# parameter F test:         F=5.0365  , p=0.0000  , df_denom=1929, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=4.6833  , p=0.0000  , df_denom=1926, df_num=24
# ssr based chi2 test:   chi2=115.2589, p=0.0000  , df=24
# likelihood ratio test: chi2=112.0211, p=0.0000  , df=24
# parameter F test:         F=4.6833  , p=0.0000  , df_denom=1926, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=4.6005  , p=0.0000  , df_denom=1923, df_num=25
# ssr based chi2 test:   chi2=118.0618, p=0.0000  , df=25
# likelihood ratio test: chi2=114.6660, p=0.0000  , df=25
# parameter F test:         F=4.6005  , p=0.0000  , df_denom=1923, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=4.4468  , p=0.0000  , df_denom=1920, df_num=26
# ssr based chi2 test:   chi2=118.8074, p=0.0000  , df=26
# likelihood ratio test: chi2=115.3677, p=0.0000  , df=26
# parameter F test:         F=4.4468  , p=0.0000  , df_denom=1920, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=4.2980  , p=0.0000  , df_denom=1917, df_num=27
# ssr based chi2 test:   chi2=119.3763, p=0.0000  , df=27
# likelihood ratio test: chi2=115.9026, p=0.0000  , df=27
# parameter F test:         F=4.2980  , p=0.0000  , df_denom=1917, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=4.1547  , p=0.0000  , df_denom=1914, df_num=28
# ssr based chi2 test:   chi2=119.7949, p=0.0000  , df=28
# likelihood ratio test: chi2=116.2955, p=0.0000  , df=28
# parameter F test:         F=4.1547  , p=0.0000  , df_denom=1914, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=4.1451  , p=0.0000  , df_denom=1911, df_num=29
# ssr based chi2 test:   chi2=123.9181, p=0.0000  , df=29
# likelihood ratio test: chi2=120.1768, p=0.0000  , df=29
# parameter F test:         F=4.1451  , p=0.0000  , df_denom=1911, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=3.9355  , p=0.0000  , df_denom=1908, df_num=30
# ssr based chi2 test:   chi2=121.8387, p=0.0000  , df=30
# likelihood ratio test: chi2=118.2177, p=0.0000  , df=30
# parameter F test:         F=3.9355  , p=0.0000  , df_denom=1908, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=3.8055  , p=0.0000  , df_denom=1905, df_num=31
# ssr based chi2 test:   chi2=121.8726, p=0.0000  , df=31
# likelihood ratio test: chi2=118.2479, p=0.0000  , df=31
# parameter F test:         F=3.8055  , p=0.0000  , df_denom=1905, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=3.7228  , p=0.0000  , df_denom=1902, df_num=32
# ssr based chi2 test:   chi2=123.2019, p=0.0000  , df=32
# likelihood ratio test: chi2=119.4975, p=0.0000  , df=32
# parameter F test:         F=3.7228  , p=0.0000  , df_denom=1902, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=4.4313  , p=0.0000  , df_denom=1899, df_num=33
# ssr based chi2 test:   chi2=151.3937, p=0.0000  , df=33
# likelihood ratio test: chi2=145.8476, p=0.0000  , df=33
# parameter F test:         F=4.4313  , p=0.0000  , df_denom=1899, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=4.4941  , p=0.0000  , df_denom=1896, df_num=34
# ssr based chi2 test:   chi2=158.3588, p=0.0000  , df=34
# likelihood ratio test: chi2=152.3012, p=0.0000  , df=34
# parameter F test:         F=4.4941  , p=0.0000  , df_denom=1896, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=4.3791  , p=0.0000  , df_denom=1893, df_num=35
# ssr based chi2 test:   chi2=159.0179, p=0.0000  , df=35
# likelihood ratio test: chi2=152.9080, p=0.0000  , df=35
# parameter F test:         F=4.3791  , p=0.0000  , df_denom=1893, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=4.4014  , p=0.0000  , df_denom=1890, df_num=36
# ssr based chi2 test:   chi2=164.5709, p=0.0000  , df=36
# likelihood ratio test: chi2=158.0352, p=0.0000  , df=36
# parameter F test:         F=4.4014  , p=0.0000  , df_denom=1890, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=4.3530  , p=0.0000  , df_denom=1887, df_num=37
# ssr based chi2 test:   chi2=167.4616, p=0.0000  , df=37
# likelihood ratio test: chi2=160.6972, p=0.0000  , df=37
# parameter F test:         F=4.3530  , p=0.0000  , df_denom=1887, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=4.2221  , p=0.0000  , df_denom=1884, df_num=38
# ssr based chi2 test:   chi2=166.9958, p=0.0000  , df=38
# likelihood ratio test: chi2=160.2648, p=0.0000  , df=38
# parameter F test:         F=4.2221  , p=0.0000  , df_denom=1884, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=3.9012  , p=0.0000  , df_denom=1881, df_num=39
# ssr based chi2 test:   chi2=158.5349, p=0.0000  , df=39
# likelihood ratio test: chi2=152.4494, p=0.0000  , df=39
# parameter F test:         F=3.9012  , p=0.0000  , df_denom=1881, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=3.7691  , p=0.0000  , df_denom=1878, df_num=40
# ssr based chi2 test:   chi2=157.2675, p=0.0000  , df=40
# likelihood ratio test: chi2=151.2736, p=0.0000  , df=40
# parameter F test:         F=3.7691  , p=0.0000  , df_denom=1878, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=3.7178  , p=0.0000  , df_denom=1875, df_num=41
# ssr based chi2 test:   chi2=159.1759, p=0.0000  , df=41
# likelihood ratio test: chi2=153.0364, p=0.0000  , df=41
# parameter F test:         F=3.7178  , p=0.0000  , df_denom=1875, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=3.6761  , p=0.0000  , df_denom=1872, df_num=42
# ssr based chi2 test:   chi2=161.4076, p=0.0000  , df=42
# likelihood ratio test: chi2=155.0961, p=0.0000  , df=42
# parameter F test:         F=3.6761  , p=0.0000  , df_denom=1872, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=3.7120  , p=0.0000  , df_denom=1869, df_num=43
# ssr based chi2 test:   chi2=167.0453, p=0.0000  , df=43
# likelihood ratio test: chi2=160.2941, p=0.0000  , df=43
# parameter F test:         F=3.7120  , p=0.0000  , df_denom=1869, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=3.6546  , p=0.0000  , df_denom=1866, df_num=44
# ssr based chi2 test:   chi2=168.4702, p=0.0000  , df=44
# likelihood ratio test: chi2=161.6031, p=0.0000  , df=44
# parameter F test:         F=3.6546  , p=0.0000  , df_denom=1866, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=3.5602  , p=0.0000  , df_denom=1863, df_num=45
# ssr based chi2 test:   chi2=168.0350, p=0.0000  , df=45
# likelihood ratio test: chi2=161.1991, p=0.0000  , df=45
# parameter F test:         F=3.5602  , p=0.0000  , df_denom=1863, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=3.4862  , p=0.0000  , df_denom=1860, df_num=46
# ssr based chi2 test:   chi2=168.3840, p=0.0000  , df=46
# likelihood ratio test: chi2=161.5171, p=0.0000  , df=46
# parameter F test:         F=3.4862  , p=0.0000  , df_denom=1860, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=3.4359  , p=0.0000  , df_denom=1857, df_num=47
# ssr based chi2 test:   chi2=169.7483, p=0.0000  , df=47
# likelihood ratio test: chi2=162.7693, p=0.0000  , df=47
# parameter F test:         F=3.4359  , p=0.0000  , df_denom=1857, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=3.3581  , p=0.0000  , df_denom=1854, df_num=48
# ssr based chi2 test:   chi2=169.6198, p=0.0000  , df=48
# likelihood ratio test: chi2=162.6477, p=0.0000  , df=48
# parameter F test:         F=3.3581  , p=0.0000  , df_denom=1854, df_num=48
# *******************************

# %% [markdown]
# Here, the null hypothesis is that we do *not* have causality, meaning that the quickly vanishing p-value for any given combination implies that we do, in fact, have causality if we include the `number` `of` `lags` displayed above the test results. This is likely spurious (infinitely many predictors will all have nonzero weights, yielding a perfect fit), but where do we toe the line?
#
# If we instead want to determine if we have causality for each *single* lag, would we just construct the lags ourselves and feed them into `granger_causality` with `max_lags` set to 1? If so, are we allowed to discretize in this fashion (i.e., include values of the time series at a set of lags instead of up to/including a given lag)?
